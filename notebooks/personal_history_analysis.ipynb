# %% [markdown]
# # Spotify Personal History Analysis
#
# Spotify API Documentation:
# * [Developer Dashboard](https://developer.spotify.com/dashboard/applications)
# * [Spotify API Documentation](https://developer.spotify.com/documentation/web-api/reference/)
#
# Spotipy (Python wrapper):
# * [readthedocs](https://spotipy.readthedocs.io/en/latest/)
# * [Github example scripts](https://github.com/plamere/spotipy/tree/master/examples)

# %%
import os
import pandas as pd
import requests
import json
import spotipy
from spotipy import util
import tqdm
tqdm.tqdm.pandas()
# from concurrent.futures import ThreadPoolExecutor
# Out:
# c:\python38\lib\site-packages\tqdm\std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### spotify data exports

# %%
# with open("../data/spotify_archive/my_spotify_data_complete/MyData/AddedToPlaylist.json", "r") as json_file:
#     data = json.load(json_file)

# %%
file_names = ["StreamingHistory"+str(i)+".json" for i in range(1,6)]

streaming_history = []
for f in file_names:
    with open(f"../data/spotify_archive/my_spotify_data_201912/MyData/{f}", "rb") as json_file:
        data = json.load(json_file, encoding="utf8")
    streaming_history = streaming_history + data

# %%
streaming_history = pd.DataFrame(streaming_history)

# %%
streaming_history.head()
# Out:
#             endTime artistName trackName  msPlayed
# 0  2019-02-25 23:12    AOBeats  Epilogue    185517
# 1  2019-02-25 23:17    AOBeats  Epilogue     11643
# 2  2019-02-25 23:20    AOBeats  Epilogue    197160
# 3  2019-02-25 23:24    AOBeats  Epilogue    197160
# 4  2019-02-25 23:27    AOBeats  Epilogue    197160

# %% [markdown]
# __create df of unique songs to get spotify info__

# %%
unique_streams = streaming_history[["artistName","trackName"]].drop_duplicates().reset_index(drop=True)

# %%
unique_streams["search_str"] =  "artist:" + unique_streams["artistName"] + " " + "track:" + unique_streams["trackName"]

# %%
unique_streams.head()
# Out:
#    artistName                 trackName  \
# 0     AOBeats                  Epilogue
# 1     AOBeats                    Duress
# 2     Mahalia     I Wish I Missed My Ex
# 3       Dagny               Used To You
# 4  Prince Fox  Space (feat. Quinn XCII)
#
#                                          search_str
# 0                     artist:AOBeats track:Epilogue
# 1                       artist:AOBeats track:Duress
# 2        artist:Mahalia track:I Wish I Missed My Ex
# 3                    artist:Dagny track:Used To You
# 4  artist:Prince Fox track:Space (feat. Quinn XCII)

# %% [markdown]
# ### spotipy search

# %%
token = util.prompt_for_user_token(
    username=os.environ["SPOTIFY_USERNAME"], # change env var
    scope="user-top-read",
    client_id=os.environ["SPOTIFY_CLIENT_ID"],
    client_secret=os.environ["SPOTIFY_CLIENT_SECRET"],
    redirect_uri='http://localhost:5000/'
)

# %%
sp = spotipy.Spotify(auth=token)

# %%
def parse_search_results(resp):
    try:
        first_result = resp["tracks"]["items"][0]
        result_dict = {}

        artist_names = []
        for artist_list in first_result["artists"]:
            name = artist_list["name"]
            artist_names.append(name)
        result_dict["artists"] = artist_names
        
        for key in ["name", "popularity", "uri"]:
            result_dict[key] = first_result[key]
            
    except IndexError:
        result_dict = {}
    return result_dict

# %%
parse_search_results(sp.search(q="artist:Dagny track:Used To You",type="track",limit=1))
# Out:
# {'artists': ['Dagny'],
#  'name': 'Used To You',
#  'popularity': 43,
#  'uri': 'spotify:track:7t3Ldw0z7zS0WyzlV7aJGV'}

# %% [markdown]
# __getting spotify track uri for all songs in streaming history__

# %%
def get_uri(search_str):
    resp = sp.search(q=search_str,type="track",limit=1)
    results = parse_search_results(resp)
    results["search_str"] = search_str
    return results

# %%
get_uri("artist:Dagny track:Used To You")
# Out:
# {'artists': ['Dagny'],
#  'name': 'Used To You',
#  'popularity': 43,
#  'uri': 'spotify:track:7t3Ldw0z7zS0WyzlV7aJGV',
#  'search_str': 'artist:Dagny track:Used To You'}

# %%
search_list = unique_streams["search_str"].values
search_results = []
for search_str in tqdm.tqdm(search_list):
    results = get_uri(search_str)
    search_results.append(results)
# Out:
#  48%|████▊     | 3273/6790 [09:15<09:58,  5.87it/s]

# %%
search_list = unique_streams["search_str"].values

# %%
# with ThreadPoolExecutor(max_workers=50) as executor:
#     results = executor.map(get_uri, search_list)

# %% [markdown]
# __getting top tracks from spotify api__

# %%
top_tracks = sp.current_user_top_tracks(time_range="short_term", limit=50)

# %%
print(sp.current_user_top_tracks.__doc__)
# Out:
#  Get the current user's top tracks
#
#             Parameters:
#                 - limit - the number of entities to return
#                 - offset - the index of the first entity to return
#                 - time_range - Over what time frame are the affinities computed
#                   Valid-values: short_term, medium_term, long_term

# %%
top_tracks_extracted = []
for t in top_tracks["items"]:
    artist_names = []
    for a in t["artists"]:
        artist_names.append(a["name"])
    top_tracks_extracted.append([t["uri"], t["name"], artist_names, t["popularity"], t["album"]["release_date"]])

# %%
top_tracks_df = pd.DataFrame(top_tracks_extracted, columns=["uri","track_name","artists","popularity","release_data"])

# %%
uri_list = top_tracks_df["uri"].values

# %%
top_tracks_df
# Out:
#                                      uri  \
# 0   spotify:track:7eJMfftS33KTjuF7lTsMCx
# 1   spotify:track:6S0nD6Kb9XYIC7z2S98dcQ
# 2   spotify:track:61UQpK8caxBw9DzrbSpxbx
# 3   spotify:track:2ptqYXyQ1QdArGjbrTzBaU
# 4   spotify:track:6LIEY7maPOCS5HILyaZRs9
# 5   spotify:track:2SL45jubSaBTVkToMFIreZ
# 6   spotify:track:7F2aEO8pNlweq3JWJyeyig
# 7   spotify:track:0D2AMu7xJhEioPG8UYlynm
# 8   spotify:track:4xxF57q6wmLa400D3AA2u2
# 9   spotify:track:0d3tkd32FV4UzyQpMsmEUD
# 10  spotify:track:3cHkjS45Xiduc6DcXtXmAo
# 11  spotify:track:2HobNDnVgZqDLmb0TPMGeI
# 12  spotify:track:5RaHbXCyGjtyBii7xJUZmP
# 13  spotify:track:4byKIKGZAu8K6kAVmBVtpp
# 14  spotify:track:5GASpj4S5zEKztFAmvqvn4
# 15  spotify:track:0FoYiNKyfSVb1YnlvkhSBS
# 16  spotify:track:75iZaRMctH8FamTOhokRVJ
# 17  spotify:track:1yfGC0bavj6t1jSGCrmABp
# 18  spotify:track:5F223mR6ZL7MQVDdt9ajdY
# 19  spotify:track:01z2fBGB8Hl3Jd3zXe4IXR
# 20  spotify:track:04UTqRsNm7ozil6lXW05dB
# 21  spotify:track:7an5x8SDHUyz4odpny1haJ
# 22  spotify:track:5M5OVOAqBib6MBJXCK8TZl
# 23  spotify:track:7B7KL2CHBbm3POwGR8uj7n
# 24  spotify:track:0XSncrobBZoW1A0bFh8Ttx
# 25  spotify:track:6CbMabu8jZmKGIYP8EZlS9
# 26  spotify:track:3URS9FbHLDKOAFRgKk9pwv
# 27  spotify:track:4jeV6FqP8W41lTYqSHcs6E
# 28  spotify:track:51SO165lWo7weEkEU8kAba
# 29  spotify:track:4LU5CO0wa6WryKRadMqFZf
# 30  spotify:track:50T7rFmLwdhDNiKGmqFtpf
# 31  spotify:track:48yUhAZGJb5WGSclZK1RAF
# 32  spotify:track:1mC2UjWt25Oixtqu7C6suL
# 33  spotify:track:6k7RfqGLqaG6o4IpwjZWMs
# 34  spotify:track:4V0691s5fLZQ4ApXTgFjGp
# 35  spotify:track:2to0Jutm0Wm9A0tCIowF13
# 36  spotify:track:6UDrfHEnUWI3O03sacM3KO
# 37  spotify:track:0T9un1tCka7l3lwsJmmLLU
# 38  spotify:track:2MpXDQlvNEbPcauGXgnHhv
# 39  spotify:track:2xlV2CuWgpPyE9e0GquKDN
# 40  spotify:track:57m2Kve0xnAgYVAPxMLKHS
# 41  spotify:track:1veoLuuMcaSn6rPACuG52I
# 42  spotify:track:3cWI6Hj9LQ0MfMuhw9uSMc
# 43  spotify:track:5FxcDJENpjWY6lL9CnbHgc
# 44  spotify:track:0Ryd8975WihbObpp5cPW1t
# 45  spotify:track:0UhKDHeZw2kHOz9HiRNFBH
# 46  spotify:track:10WSRKXFiyAGc0g6wZHigw
# 47  spotify:track:1RMJfOjuWNkfdjDo038CgU
# 48  spotify:track:1VTicwJhhJloai3UNWzzVW
# 49  spotify:track:1XXOLEun0Duy8720pFpQ8Y
#
#                                            track_name  \
# 0   death bed (coffee for your head) (feat. beabad...
# 1                 Moon (feat. Vancouver Sleep Clinic)
# 2                                             You Are
# 3                                      Crazier Things
# 4                                                Body
# 5                                              Right?
# 6                                    How Does It Feel
# 7                         lovesick. (Yoke Lore Remix)
# 8                                         The Weather
# 9                                            Play God
# 10                                   Running Thru 3AM
# 11                                  Creature Comforts
# 12                                             SUCKER
# 13                            Modern Flame - Acoustic
# 14                                               Body
# 15                           IDWK - Loud Luxury Remix
# 16                                          Faking It
# 17                         Sink or Swim (feat. Daysi)
# 18                                              Crazy
# 19                                 Come Back to Earth
# 20                       Always There When I Need You
# 21                                          Berkshire
# 22                                    How To Be Human
# 23                        Messy - Sweater Beats Remix
# 24                                       say it first
# 25                                              Manic
# 26                                    Don't Walk Away
# 27                                          sucks 4 u
# 28                                                  X
# 29                                  maybe, i'm afraid
# 30                                                 nj
# 31                                          Same Room
# 32  Don't Leave Me Alone (feat. Anne-Marie) - EDX'...
# 33                          Serious - TWO LANES Remix
# 34                                              Drive
# 35                                           Doorstep
# 36                               Leaving (feat. Yuna)
# 37                                    FEELS LIKE HOME
# 38                Hallucinogenics - Vallis Alps Remix
# 39                                    Someone To Stay
# 40                                  tear myself apart
# 41                                Better By Your Side
# 42                                   Lost Without You
# 43                   go with u - Louis La Roche Remix
# 44                      boyfriend (with Social House)
# 45                                            Josslyn
# 46                                       Don't Let Go
# 47                                               Mine
# 48                           I Like (the idea of) You
# 49                                   Wake up with You
#
#                                      artists  popularity release_data
# 0                       [Powfu, beabadoobee]          98   2020-02-08
# 1              [OTR, Vancouver Sleep Clinic]          51   2020-03-06
# 2                                    [Tvvin]          37   2019-03-06
# 3                           [Chelsea Cutler]          62   2020-01-17
# 4                                   [Fintan]          14   2019-03-22
# 5                                   [McCall]          23   2019-08-16
# 6                            [papichuloteej]          45   2020-01-28
# 7                        [FINLAY, Yoke Lore]          28   2019-07-12
# 8                                 [Lawrence]          53   2020-02-21
# 9                                     [Refs]          29   2019-06-07
# 10                             [Aeris Roves]          50   2018-11-02
# 11                                  [Trella]          41   2018-08-10
# 12                        [Tyzo Bloom, GiGi]          45   2019-08-30
# 13                        [Emmit Fenn, Yuna]          24   2017-08-02
# 14                                     [Wet]          39   2016-01-29
# 15           [DVBBS, blackbear, Loud Luxury]          47   2018-08-03
# 16                             [Sasha Sloan]          54   2018-11-29
# 17                       [Bloom Line, Daysi]          41   2019-02-22
# 18                                   [Effee]          40   2019-04-25
# 19                              [Mac Miller]          72   2018-08-03
# 20                          [Salt Cathedral]          43   2017-06-21
# 21                             [LAUNDRY DAY]          38   2018-03-23
# 22                          [Chelsea Cutler]          58   2020-01-17
# 23                   [Kiiara, Sweater Beats]          22   2018-07-14
# 24                              [ROLE MODEL]          58   2019-11-13
# 25                            [Coleman Hell]          39   2018-01-31
# 26                          [Łaszewo, KEEVΛ]          39   2019-04-04
# 27                           [Silver Sphere]          43   2019-10-02
# 28                                   [Majik]          36   2018-07-11
# 29                           [lovelytheband]          59   2018-08-03
# 30                          [Chelsea Cutler]          54   2020-01-17
# 31                                 [JP Saxe]          62   2019-06-28
# 32           [David Guetta, Anne-Marie, EDX]          60   2019-05-08
# 33  [Midnight Kids, Matthew Koma, TWO LANES]          39   2019-02-01
# 34                             [OTR, Panama]          51   2019-10-04
# 35                               [Izzy Bizu]          44   2019-05-03
# 36                             [Ekali, Yuna]          57   2018-09-28
# 37                [Bea Miller, Jessie Reyez]          61   2019-08-23
# 38                [Matt Maeson, Vallis Alps]          55   2016-02-04
# 39                  [Vancouver Sleep Clinic]          62   2017-04-07
# 40                              [Tate McRae]          71   2019-08-28
# 41                       [Aeble, Tom Aspaul]          57   2016-11-04
# 42                           [Freya Ridings]          71   2019-07-19
# 43                   [BAYNK, Louis La Roche]          55   2019-11-15
# 44             [Ariana Grande, Social House]          83   2019-08-02
# 45                          [Olivia O'Brien]          68   2020-02-07
# 46                                 [Mafalda]          22   2016-08-25
# 47                             [Phoebe Ryan]          52   2015-06-09
# 48                            [Tessa Violet]          55   2019-10-25
# 49                            [Emerson Leif]          44   2019-10-15

# %% [markdown]
# __track info for top tracks__

# %%
audio_features = []
audio_analysis = []
for uri in tqdm.tqdm(uri_list):
    af = sp.audio_features(uri)
    aa = sp.audio_analysis(uri)
    audio_features.append(af[0])
    audio_analysis.append(aa)
# Out:
# 100%|██████████| 50/50 [00:28<00:00,  1.75it/s]

# %%
af_df = pd.DataFrame(audio_features)

# %%
aa_df = pd.DataFrame(audio_analysis)

# %%
aa.keys()
# Out:
# dict_keys(['meta', 'track', 'bars', 'beats', 'tatums', 'sections', 'segments'])

# %%
top_tracks_df = top_tracks_df.merge(af_df,on="uri",how="left")
top_tracks_df = top_tracks_df.merge(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-5df1cd9b539c> in <module>
#       1 top_tracks_df = top_tracks_df.merge(af_df,on="uri",how="left")
# ----> 2 top_tracks_df = top_tracks_df.merge(a)
#
# c:\python38\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7282         from pandas.core.reshape.merge import merge
#    7283
# -> 7284         return merge(
#    7285             self,
#    7286             right,
#
# c:\python38\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# c:\python38\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     570     ):
#     571         _left = _validate_operand(left)
# --> 572         _right = _validate_operand(right)
#     573         self.left = self.orig_left = _left
#     574         self.right = self.orig_right = _right
#
# c:\python38\lib\site-packages\pandas\core\reshape\merge.py in _validate_operand(obj)
#    2004             return obj.to_frame()
#    2005     else:
# -> 2006         raise TypeError(
#    2007             "Can only merge Series or DataFrame objects, "
#    2008             "a {obj} was passed".format(obj=type(obj))
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'dict'> was passed

# %%
top_tracks_df.describe()
